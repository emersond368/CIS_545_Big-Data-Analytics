# %%
def get_class(amino_acid):
    
    #Aliphatic class
    if amino_acid in ['G','A','V','L','I']:
        return 'Aliphatic'
    #Hydroxyl/Selenium/Sulfur class
    elif amino_acid in ['S','C','T','M']:
        return 'Hydroxyl'
    #Cyclic class
    elif amino_acid in ['P']:
        return 'Cyclic'
    #Aromatic class
    elif amino_acid in ['F','Y','W']:
        return 'Aromatic'
    #Basic class
    elif amino_acid in ['H','K','R']:
        return 'Basic'
    #Acidic/Amide class
    else:
        return 'Acidic'

def levenshtein(s1, s2):
    s1 = ''.join(s1)
    s2 = ''.join(s2)
    
    if len(s1) < len(s2):
        return levenshtein(s2, s1)

    # len(s1) >= len(s2)
    if len(s2) == 0:
        return len(s1)

    previous_row = range(len(s2) + 1)
    for i, c1 in enumerate(s1):
        current_row = [i + 1]
        for j, c2 in enumerate(s2):
            #evaluate from above
            insertions = previous_row[j + 1] + 1 
            #evluate from left
            deletions = current_row[j] + 1
            #evaluate from diagonal above
            substitutions = previous_row[j] + (get_class(c1) != get_class(c2))
            current_row.append(min(insertions, deletions, substitutions))      
        previous_row = current_row
    
    return previous_row[-1]

# %%
import sys
fasta = {}
with open('proteins.fasta') as file_one:
    for line in file_one:
        line = line.strip()
        if not line:
            continue
        if line.startswith(">"):
            active_sequence_name = line[1:]
            if active_sequence_name not in fasta:
                fasta[active_sequence_name] = []
            continue
        sequence = line
        sequence = ''.join(sequence)
        fasta[active_sequence_name].append(sequence)
for keys in fasta:
    flattened = [val for sublist in fasta[keys] for val in sublist]
    fasta[keys] = flattened

# %%
def output_k_homologs(reference,test):
    
    reference = ''.join(reference)
    LD = {}
    for keys in test:
        LD[keys] = levenshtein(reference,test[keys])
        
    return LD

# %% [markdown]
# ## Step 3.1

# %%
levenshtein(fasta['NP_001157030.1 prolactin precursor [Homo sapiens]'],
    ['PIDNYLKLLKCRIIHNNNC'])
# Out:
# 208

# %%
LD = output_k_homologs(fasta['NP_001157030.1 prolactin precursor [Homo sapiens]'],fasta)
from operator import itemgetter
sorted_LD = sorted(LD.items(), key=itemgetter(1))
sorted_LD
# Out:
# [('NP_001157030.1 prolactin precursor [Homo sapiens]', 0),
#  ('XP_011513055.1 PREDICTED: prolactin isoform X1 [Homo sapiens]', 1),
#  ('XP_011513056.1 PREDICTED: prolactin isoform X1 [Homo sapiens]', 1),
#  ('XP_014991125.1 PREDICTED: prolactin isoform X2 [Macaca mulatta]', 2),
#  ('XP_002816520.2 PREDICTED: prolactin [Pongo abelii]', 2),
#  ('NP_001040593.1 prolactin precursor [Macaca mulatta]', 2),
#  ('XP_005553987.1 PREDICTED: prolactin isoform X2 [Macaca fascicularis]', 3),
#  ('XP_011740959.1 PREDICTED: prolactin isoform X2 [Macaca nemestrina]', 3),
#  ('XP_018885279.1 PREDICTED: prolactin [Gorilla gorilla gorilla]', 3),
#  ('XP_011886824.1 PREDICTED: prolactin isoform X2 [Cercocebus atys]', 3),
#  ('XP_009448859.1 PREDICTED: prolactin isoform X2 [Pan troglodytes]', 3),
#  ('XP_004043380.1 PREDICTED: prolactin [Gorilla gorilla gorilla]', 3),
#  ('XP_014991124.1 PREDICTED: prolactin isoform X1 [Macaca mulatta]', 3),
#  ('XP_012364516.1 PREDICTED: prolactin [Nomascus leucogenys]', 3),
#  ('XP_016810474.1 PREDICTED: prolactin isoform X2 [Pan troglodytes]', 3),
#  ('XP_011853557.1 PREDICTED: prolactin [Mandrillus leucophaeus]', 3),
#  ('XP_015305340.1 PREDICTED: prolactin isoform X2 [Macaca fascicularis]', 3),
#  ('XP_008975038.1 PREDICTED: prolactin [Pan paniscus]', 3),
#  ('XP_003263607.1 PREDICTED: prolactin [Nomascus leucogenys]', 3),
#  ('XP_011740958.1 PREDICTED: prolactin isoform X1 [Macaca nemestrina]', 4),
#  ('XP_005553986.1 PREDICTED: prolactin isoform X1 [Macaca fascicularis]', 4),
#  ('XP_007971759.1 PREDICTED: prolactin isoform X2 [Chlorocebus sabaeus]', 4),
#  ('XP_011886823.1 PREDICTED: prolactin isoform X1 [Cercocebus atys]', 4),
#  ('XP_017728587.1 PREDICTED: prolactin isoform X2 [Rhinopithecus bieti]', 4),
#  ('XP_009448858.1 PREDICTED: prolactin isoform X1 [Pan troglodytes]', 4),
#  ('XP_017728588.1 PREDICTED: prolactin isoform X2 [Rhinopithecus bieti]', 4),
#  ('XP_007971758.1 PREDICTED: prolactin isoform X2 [Chlorocebus sabaeus]', 4),
#  ('XP_010352398.1 PREDICTED: prolactin isoform X2 [Rhinopithecus roxellana]',
#   4),
#  ('XP_003897163.1 PREDICTED: prolactin isoform X2 [Papio anubis]', 4),
#  ('XP_009202762.1 PREDICTED: prolactin isoform X1 [Papio anubis]', 5),
#  ('XP_010352397.1 PREDICTED: prolactin isoform X1 [Rhinopithecus roxellana]',
#   5),
#  ('XP_011818159.1 PREDICTED: prolactin [Colobus angolensis palliatus]', 5),
#  ('XP_017728586.1 PREDICTED: prolactin isoform X1 [Rhinopithecus bieti]', 5),
#  ('XP_007971757.1 PREDICTED: prolactin isoform X1 [Chlorocebus sabaeus]', 5),
#  ('XP_012313939.1 PREDICTED: prolactin [Aotus nancymaae]', 7),
#  ('XP_017399571.1 PREDICTED: prolactin [Cebus capucinus imitator]', 8),
#  ('XP_008992140.1 PREDICTED: prolactin [Callithrix jacchus]', 9),
#  ('XP_002746227.1 PREDICTED: prolactin [Callithrix jacchus]', 9),
#  ('XP_003927357.1 PREDICTED: prolactin [Saimiri boliviensis boliviensis]', 9),
#  ('XP_006860847.1 PREDICTED: prolactin [Chrysochloris asiatica]', 28),
#  ('XP_006182282.1 PREDICTED: prolactin isoform X2 [Camelus ferus]', 29),
#  ('XP_004712528.1 PREDICTED: prolactin [Echinops telfairi]', 29),
#  ('XP_010978421.1 PREDICTED: prolactin [Camelus dromedarius]', 29),
#  ('XP_010972551.1 PREDICTED: prolactin [Camelus bactrianus]', 29),
#  ('XP_007197206.1 PREDICTED: prolactin isoform X2 [Balaenoptera acutorostrata scammoni]',
#   29),
#  ('NP_001008276.2 prolactin precursor [Canis lupus familiaris]', 29),
#  ('XP_012609144.1 prolactin [Microcebus murinus]', 29),
#  ('XP_008705942.1 PREDICTED: prolactin [Ursus maritimus]', 30),
#  ('XP_015349688.1 PREDICTED: prolactin [Marmota marmota marmota]', 30),
#  ('XP_005329209.1 PREDICTED: prolactin isoform X2 [Ictidomys tridecemlineatus]',
#   30),
#  ('NP_001291863.1 prolactin precursor [Ailuropoda melanoleuca]', 30),
#  ('XP_007197205.1 PREDICTED: prolactin isoform X1 [Balaenoptera acutorostrata scammoni]',
#   30),
#  ('XP_012413184.1 PREDICTED: prolactin isoform X2 [Trichechus manatus latirostris]',
#   30),
#  ('XP_014412700.1 PREDICTED: prolactin isoform X1 [Camelus ferus]', 30),
#  ('XP_015090070.1 PREDICTED: prolactin isoform X2 [Vicugna pacos]', 30),
#  ('XP_004273577.1 PREDICTED: prolactin isoform X2 [Orcinus orca]', 30),
#  ('XP_004432137.1 PREDICTED: prolactin [Ceratotherium simum simum]', 31),
#  ('XP_015090069.1 PREDICTED: prolactin isoform X1 [Vicugna pacos]', 31),
#  ('NP_001075365.1 prolactin precursor [Equus caballus]', 31),
#  ('XP_008524684.1 PREDICTED: prolactin [Equus przewalskii]', 31),
#  ('XP_012494102.1 PREDICTED: prolactin [Propithecus coquereli]', 31),
#  ('XP_004384051.1 PREDICTED: prolactin isoform X1 [Trichechus manatus latirostris]',
#   31),
#  ('XP_004317299.1 PREDICTED: prolactin isoform X2 [Tursiops truncatus]', 31),
#  ('XP_005665681.1 PREDICTED: prolactin isoform X1 [Sus scrofa]', 31),
#  ('XP_005329210.1 PREDICTED: prolactin isoform X1 [Ictidomys tridecemlineatus]',
#   31),
#  ('XP_012389802.1 PREDICTED: prolactin isoform X1 [Orcinus orca]', 31),
#  ('NP_999091.1 prolactin precursor [Sus scrofa]', 32),
#  ('XP_007950297.1 PREDICTED: prolactin isoform X2 [Orycteropus afer afer]',
#   32),
#  ('XP_007074595.1 PREDICTED: prolactin [Panthera tigris altaica]', 32),
#  ('XP_004593148.1 PREDICTED: prolactin isoform X2 [Ochotona princeps]', 32),
#  ('XP_004417747.1 PREDICTED: prolactin [Odobenus rosmarus divergens]', 32),
#  ('XP_016007352.1 PREDICTED: prolactin isoform X2 [Rousettus aegyptiacus]',
#   32),
#  ('XP_014941384.1 PREDICTED: prolactin [Acinonyx jubatus]', 33),
#  ('XP_004593147.1 PREDICTED: prolactin isoform X1 [Ochotona princeps]', 33),
#  ('XP_016063979.1 PREDICTED: prolactin isoform X2 [Miniopterus natalensis]',
#   33),
#  ('XP_006909294.1 PREDICTED: prolactin isoform X2 [Pteropus alecto]', 33),
#  ('NP_001036806.1 prolactin precursor [Felis catus]', 33),
#  ('XP_007950290.1 PREDICTED: prolactin isoform X1 [Orycteropus afer afer]',
#   33),
#  ('XP_016007350.1 PREDICTED: prolactin isoform X1 [Rousettus aegyptiacus]',
#   33),
#  ('NP_001076144.1 prolactin precursor [Oryctolagus cuniculus]', 34),
#  ('XP_016063978.1 PREDICTED: prolactin isoform X1 [Miniopterus natalensis]',
#   34),
#  ('XP_003788427.1 PREDICTED: prolactin [Otolemur garnettii]', 34),
#  ('XP_004761314.1 PREDICTED: prolactin [Mustela putorius furo]', 34),
#  ('XP_006909293.1 PREDICTED: prolactin isoform X1 [Pteropus alecto]', 34),
#  ('XP_014721713.1 PREDICTED: prolactin isoform X2 [Equus asinus]', 35),
#  ('XP_014589686.1 PREDICTED: prolactin isoform X1 [Equus caballus]', 36),
#  ('XP_014721646.1 PREDICTED: prolactin isoform X1 [Equus asinus]', 36),
#  ('XP_007525213.1 PREDICTED: prolactin [Erinaceus europaeus]', 36),
#  ('XP_004614023.1 PREDICTED: prolactin [Sorex araneus]', 37),
#  ('XP_004693372.1 PREDICTED: prolactin [Condylura cristata]', 37),
#  ('XP_017498313.1 PREDICTED: prolactin [Manis javanica]', 38),
#  ('NP_001272476.1 prolactin precursor [Capra hircus]', 39),
#  ('XP_003760185.1 PREDICTED: prolactin [Sarcophilus harrisii]', 39),
#  ('XP_008592067.1 PREDICTED: prolactin [Galeopterus variegatus]', 40),
#  ('NP_776378.2 prolactin precursor [Bos taurus]', 40),
#  ('XP_010843869.1 PREDICTED: prolactin [Bison bison bison]', 40),
#  ('XP_005894334.1 PREDICTED: prolactin isoform X2 [Bos mutus]', 40),
#  ('XP_019841745.1 PREDICTED: prolactin [Bos indicus]', 40),
#  ('XP_008070267.1 PREDICTED: prolactin [Carlito syrichta]', 41),
#  ('NP_001277814.1 prolactin-like precursor [Bubalus bubalis]', 41),
#  ('XP_014333241.1 PREDICTED: prolactin isoform X1 [Bos mutus]', 41),
#  ('XP_012890690.1 PREDICTED: prolactin isoform X3 [Dipodomys ordii]', 42),
#  ('XP_012890688.1 PREDICTED: prolactin isoform X2 [Dipodomys ordii]', 43),
#  ('NP_001028166.1 prolactin precursor [Monodelphis domestica]', 44),
#  ('XP_012890687.1 PREDICTED: prolactin isoform X1 [Dipodomys ordii]', 44),
#  ('XP_004462110.1 PREDICTED: prolactin [Dasypus novemcinctus]', 45),
#  ('XP_003416493.1 PREDICTED: prolactin [Loxodonta africana]', 47),
#  ('XP_008144290.1 PREDICTED: prolactin [Eptesicus fuscus]', 50),
#  ('XP_005434977.1 PREDICTED: prolactin [Falco cherrug]', 50),
#  ('XP_005235773.1 PREDICTED: prolactin [Falco peregrinus]', 50),
#  ('NP_001009306.1 prolactin precursor [Ovis aries]', 50),
#  ('XP_009885141.1 PREDICTED: prolactin isoform X1 [Charadrius vociferus]', 51),
#  ('XP_015470772.1 PREDICTED: prolactin [Parus major]', 51),
#  ('XP_005525306.1 PREDICTED: prolactin [Pseudopodoces humilis]', 51),
#  ('XP_010197598.1 PREDICTED: prolactin [Colius striatus]', 51),
#  ('XP_017663895.1 PREDICTED: prolactin [Lepidothrix coronata]', 51),
#  ('XP_008918077.1 PREDICTED: prolactin [Manacus vitellinus]', 51),
#  ('XP_010140579.1 PREDICTED: prolactin [Buceros rhinoceros silvestris]', 51),
#  ('XP_006121901.1 PREDICTED: prolactin [Pelodiscus sinensis]', 52),
#  ('NP_001297301.1 prolactin precursor [Anas platyrhynchos]', 52),
#  ('XP_006757346.1 PREDICTED: prolactin [Myotis davidii]', 52),
#  ('XP_008943294.1 PREDICTED: prolactin [Merops nubicus]', 52),
#  ('XP_009971474.1 PREDICTED: prolactin [Tyto alba]', 52),
#  ('XP_014796282.1 PREDICTED: prolactin isoform X1 [Calidris pugnax]', 52),
#  ('XP_014733380.1 PREDICTED: prolactin [Sturnus vulgaris]', 52),
#  ('XP_009865818.1 PREDICTED: prolactin [Apaloderma vittatum]', 52),
#  ('XP_013040275.1 PREDICTED: prolactin [Anser cygnoides domesticus]', 52),
#  ('XP_009949788.1 PREDICTED: prolactin [Leptosomus discolor]', 52),
#  ('NP_990797.2 prolactin precursor [Gallus gallus]', 52),
#  ('XP_009939558.1 PREDICTED: prolactin [Opisthocomus hoazin]', 53),
#  ('XP_013796677.1 PREDICTED: prolactin [Apteryx australis mantelli]', 53),
#  ('NP_001268485.1 prolactin precursor [Melopsittacus undulatus]', 53),
#  ('XP_009636228.1 PREDICTED: prolactin [Egretta garzetta]', 53),
#  ('XP_014796283.1 PREDICTED: prolactin isoform X2 [Calidris pugnax]', 53),
#  ('XP_010401216.1 prolactin [Corvus cornix cornix]', 53),
#  ('XP_009499663.1 PREDICTED: prolactin [Phalacrocorax carbo]', 53),
#  ('XP_009706816.1 PREDICTED: prolactin [Cariama cristata]', 53),
#  ('XP_010290081.1 PREDICTED: prolactin [Phaethon lepturus]', 53),
#  ('XP_008629132.1 PREDICTED: prolactin [Corvus brachyrhynchos]', 53),
#  ('XP_010018153.1 PREDICTED: prolactin [Nestor notabilis]', 53),
#  ('XP_009076160.1 PREDICTED: prolactin [Acanthisitta chloris]', 54),
#  ('XP_009478533.1 PREDICTED: prolactin [Pelecanus crispus]', 54),
#  ('XP_010083120.1 PREDICTED: prolactin [Pterocles gutturalis]', 54),
#  ('XP_010146310.1 PREDICTED: prolactin [Eurypyga helias]', 54),
#  ('XP_010210263.1 PREDICTED: prolactin isoform X2 [Tinamus guttatus]', 54),
#  ('XP_009324786.1 PREDICTED: prolactin [Pygoscelis adeliae]', 54),
#  ('XP_009581913.1 PREDICTED: prolactin [Fulmarus glacialis]', 54),
#  ('XP_009283365.1 PREDICTED: prolactin [Aptenodytes forsteri]', 54),
#  ('XP_009687033.1 PREDICTED: prolactin [Struthio camelus australis]', 54),
#  ('XP_005506081.1 PREDICTED: prolactin [Columba livia]', 54),
#  ('XP_009473674.1 PREDICTED: prolactin [Nipponia nippon]', 54),
#  ('NP_001290115.1 prolactin precursor [Meleagris gallopavo]', 55),
#  ('XP_006030519.1 PREDICTED: prolactin [Alligator sinensis]', 55),
#  ('XP_009904855.1 PREDICTED: prolactin [Picoides pubescens]', 55),
#  ('XP_010120460.1 PREDICTED: prolactin [Chlamydotis macqueenii]', 55),
#  ('XP_005041658.1 PREDICTED: prolactin [Ficedula albicollis]', 55),
#  ('XP_009806084.1 PREDICTED: prolactin [Gavia stellata]', 55),
#  ('XP_010210262.1 PREDICTED: prolactin isoform X1 [Tinamus guttatus]', 56),
#  ('XP_009092142.1 PREDICTED: prolactin [Serinus canaria]', 56),
#  ('XP_009913904.1 PREDICTED: prolactin isoform X1 [Haliaeetus albicilla]', 56),
#  ('XP_015673876.1 PREDICTED: prolactin [Protobothrops mucrosquamatus]', 56),
#  ('XP_005421022.1 PREDICTED: prolactin [Geospiza fortis]', 56),
#  ('XP_010571454.1 PREDICTED: prolactin isoform X1 [Haliaeetus leucocephalus]',
#   56),
#  ('XP_005481833.1 PREDICTED: prolactin [Zonotrichia albicollis]', 56),
#  ('XP_009562462.1 PREDICTED: prolactin [Cuculus canorus]', 57),
#  ('XP_015284438.1 PREDICTED: prolactin [Gekko japonicus]', 57),
#  ('XP_005355044.1 PREDICTED: prolactin [Microtus ochrogaster]', 57),
#  ('XP_005870041.1 PREDICTED: prolactin [Myotis brandtii]', 57),
#  ('XP_007435104.1 PREDICTED: prolactin [Python bivittatus]', 57),
#  ('XP_010002820.1 PREDICTED: prolactin [Chaetura pelagica]', 57),
#  ('XP_006995480.1 PREDICTED: prolactin isoform X1 [Peromyscus maniculatus bairdii]',
#   57),
#  ('XP_008162696.1 PREDICTED: prolactin [Chrysemys picta bellii]', 57),
#  ('XP_006253974.1 PREDICTED: prolactin isoform X1 [Rattus norvegicus]', 58),
#  ('XP_011579497.1 PREDICTED: prolactin [Aquila chrysaetos canadensis]', 58),
#  ('XP_008852937.1 PREDICTED: prolactin [Nannospalax galili]', 58),
#  ('XP_019375547.1 PREDICTED: prolactin [Gavialis gangeticus]', 59),
#  ('XP_012965974.1 PREDICTED: prolactin isoform X1 [Mesocricetus auratus]', 59),
#  ('XP_009885142.1 PREDICTED: prolactin isoform X2 [Charadrius vociferus]', 59),
#  ('NP_036761.1 prolactin precursor [Rattus norvegicus]', 59),
#  ('XP_019345919.1 PREDICTED: prolactin [Alligator mississippiensis]', 59),
#  ('XP_010571455.1 PREDICTED: prolactin isoform X2 [Haliaeetus leucocephalus]',
#   60),
#  ('XP_019412311.1 PREDICTED: prolactin [Crocodylus porosus]', 60),
#  ('XP_006093806.1 PREDICTED: LOW QUALITY PROTEIN: prolactin [Myotis lucifugus]',
#   60),
#  ('NP_001268581.1 prolactin precursor [Mesocricetus auratus]', 60),
#  ('XP_009913905.1 PREDICTED: prolactin isoform X2 [Haliaeetus albicilla]', 60),
#  ('XP_010301083.1 PREDICTED: prolactin [Balearica regulorum gibbericeps]', 60),
#  ('NP_001157002.1 prolactin isoform 2 precursor [Mus musculus]', 60),
#  ('NP_001093699.1 prolactin [Xenopus tropicalis]', 60),
#  ('NP_001086486.1 prolactin, gene 1 L homeolog [Xenopus laevis]', 61),
#  ('XP_007636186.1 PREDICTED: prolactin [Cricetulus griseus]', 61),
#  ('XP_008500498.1 PREDICTED: prolactin [Calypte anna]', 61),
#  ('NP_035294.2 prolactin isoform 1 precursor [Mus musculus]', 61),
#  ('XP_015710248.1 PREDICTED: prolactin [Coturnix japonica]', 61),
#  ('XP_003509882.1 PREDICTED: prolactin [Cricetulus griseus]', 62),
#  ('XP_017200268.1 PREDICTED: prolactin isoform X1 [Oryctolagus cuniculus]',
#   63),
#  ('XP_008107003.1 PREDICTED: prolactin [Anolis carolinensis]', 63),
#  ('XP_018419295.1 PREDICTED: prolactin [Nanorana parkeri]', 63),
#  ('XP_015844330.1 PREDICTED: prolactin isoform X2 [Peromyscus maniculatus bairdii]',
#   66),
#  ('XP_014333243.1 PREDICTED: prolactin isoform X3 [Bos mutus]', 66),
#  ('XP_004847671.1 PREDICTED: prolactin [Heterocephalus glaber]', 67),
#  ('NP_001089341.1 uncharacterized protein LOC734391 [Xenopus laevis]', 67),
#  ('XP_010621244.1 PREDICTED: prolactin [Fukomys damarensis]', 69),
#  ('XP_005403436.1 PREDICTED: prolactin [Chinchilla lanigera]', 69),
#  ('NP_001274128.1 prolactin precursor [Vicugna pacos]', 72),
#  ('NP_001182038.1 prolactin precursor [Cavia porcellus]', 74),
#  ('XP_003509886.1 PREDICTED: prolactin [Cricetulus griseus]', 80),
#  ('XP_007636184.1 PREDICTED: prolactin [Cricetulus griseus]', 80),
#  ('NP_001159915.1 prolactin, gene 2 L homeolog [Xenopus laevis]', 85),
#  ('NP_742167.1 prolactin family 3, subfamily d, member 1 precursor [Mus musculus]',
#   89),
#  ('NP_080172.1 prolactin family 3, subfamily a, member 1 precursor [Mus musculus]',
#   90),
#  ('NP_742168.1 prolactin family 3, subfamily d, member 3 precursor [Mus musculus]',
#   90),
#  ('NP_714958.1 Prolactin family 3, subfamily a, member 1 precursor [Rattus norvegicus]',
#   90),
#  ('XP_006516703.1 PREDICTED: prolactin family 3, subfamily d, member 3 isoform X1 [Mus musculus]',
#   90),
#  ('XP_006516702.1 PREDICTED: prolactin family 3, subfamily d, member 1 isoform X1 [Mus musculus]',
#   90),
#  ('XP_010179515.1 PREDICTED: prolactin, partial [Mesitornis unicolor]', 91),
#  ('NP_001077409.3 Prolactin family 3, subfamily d, member 2 precursor [Rattus norvegicus]',
#   94),
#  ('NP_001038997.1 Prolactin family 2, subfamily c, member 1 precursor [Mus musculus]',
#   94),
#  ('XP_008769893.1 PREDICTED: prolactin family 3, subfamily d, member 2 isoform X1 [Rattus norvegicus]',
#   95),
#  ('XP_006516790.1 PREDICTED: prolactin family 2, subfamily c, member 1 isoform X1 [Mus musculus]',
#   95),
#  ('NP_001037736.1 Prolactin family 2, subfamily c, member 1 precursor [Rattus norvegicus]',
#   95),
#  ('XP_014441987.1 PREDICTED: prolactin [Tupaia chinensis]', 96),
#  ('XP_010899486.1 PREDICTED: prolactin [Esox lucius]', 96),
#  ('XP_010634632.1 PREDICTED: prolactin [Fukomys damarensis]', 96),
#  ('XP_020387765.1 prolactin [Rhincodon typus]', 97),
#  ('XP_010903501.1 PREDICTED: prolactin [Esox lucius]', 98),
#  ('XP_020341811.1 prolactin [Oncorhynchus kisutch]', 99),
#  ('NP_001118205.1 prolactin precursor [Oncorhynchus mykiss]', 99),
#  ('XP_012738352.1 PREDICTED: prolactin [Fundulus heteroclitus]', 99),
#  ('NP_001117140.1 prolactin precursor [Salmo salar]', 99),
#  ('XP_019128438.1 PREDICTED: prolactin [Larimichthys crocea]', 99),
#  ('NP_001279575.1 prolactin precursor [Callorhinchus milii]', 100),
#  ('NP_001316286.1 prolactin-like precursor [Kryptolebias marmoratus]', 101),
#  ('NP_036084.2 prolactin family 2, subfamily c, member 4 precursor [Mus musculus]',
#   101),
#  ('NP_001266721.2 prolactin precursor [Oreochromis niloticus]', 101),
#  ('NP_001156326.1 prolactin 2 precursor [Danio rerio]', 101),
#  ('NP_001266715.1 prolactin precursor [Oreochromis niloticus]', 101),
#  ('XP_017351132.1 PREDICTED: prolactin [Ictalurus punctatus]', 101),
#  ('NP_001298058.1 prolactin family 2, subfamily c, member 5 isoform 1 precursor [Mus musculus]',
#   103),
#  ('NP_001265831.1 prolactin precursor [Oryzias latipes]', 103),
#  ('NP_001038167.1 prolactin family 5, subfamily a, member 2 precursor [Rattus norvegicus]',
#   103),
#  ('XP_013919564.1 PREDICTED: prolactin [Thamnophis sirtalis]', 103),
#  ('XP_019966165.1 PREDICTED: prolactin [Paralichthys olivaceus]', 103),
#  ('NP_001072092.1 prolactin precursor [Takifugu rubripes]', 103),
#  ('XP_018931550.1 PREDICTED: prolactin [Cyprinus carpio]', 103),
#  ('NP_862900.1 prolactin family 2, subfamily c, member 5 isoform 2 precursor [Mus musculus]',
#   103),
#  ('NP_064464.1 prolactin family 8, subfamily a, member 3 precursor [Rattus norvegicus]',
#   104),
#  ('XP_018934351.1 PREDICTED: prolactin [Cyprinus carpio]', 104),
#  ('XP_008399773.1 PREDICTED: prolactin [Poecilia reticulata]', 104),
#  ('NP_852102.2 prolactin [Danio rerio]', 104),
#  ('XP_016091955.1 PREDICTED: prolactin [Sinocyclocheilus grahami]', 106),
#  ('XP_016397133.1 PREDICTED: prolactin [Sinocyclocheilus rhinocerous]', 106),
#  ('XP_014830421.1 PREDICTED: prolactin [Poecilia mexicana]', 106),
#  ('XP_016302543.1 PREDICTED: prolactin [Sinocyclocheilus anshuiensis]', 106),
#  ('XP_007541154.1 PREDICTED: prolactin [Poecilia formosa]', 106),
#  ('XP_016343318.1 PREDICTED: prolactin [Sinocyclocheilus anshuiensis]', 107),
#  ('XP_010634631.1 PREDICTED: prolactin [Fukomys damarensis]', 108),
#  ('XP_006253968.1 PREDICTED: prolactin family 8, subfamily a, member 2 isoform X1 [Rattus norvegicus]',
#   110),
#  ('NP_074037.1 prolactin family 8, subfamily a, member 2 precursor [Rattus norvegicus]',
#   110),
#  ('NP_082753.1 prolactin family 8, subfamily a, member 1 precursor [Mus musculus]',
#   111),
#  ('XP_010747002.1 PREDICTED: prolactin [Larimichthys crocea]', 111),
#  ('XP_007657220.1 PREDICTED: LOW QUALITY PROTEIN: prolactin [Ornithorhynchus anatinus]',
#   112),
#  ('XP_014785320.1 PREDICTED: chymotrypsin B-like [Octopus bimaculoides]', 117),
#  ('NP_001276848.1 prolactin family 8, subfamily a, member 2 isoform 2 precursor [Mus musculus]',
#   118),
#  ('NP_034218.1 prolactin family 8, subfamily a, member 2 isoform 1 precursor [Mus musculus]',
#   118),
#  ('NP_001008342.1 prolactin family 7, subfamily a, member 4 precursor [Rattus norvegicus]',
#   119),
#  ('XP_014047868.1 PREDICTED: prolactin isoform X1 [Salmo salar]', 119),
#  ('XP_009981608.1 PREDICTED: prolactin, partial [Tauraco erythrolophus]', 120),
#  ('XP_010170454.1 PREDICTED: prolactin, partial [Antrostomus carolinensis]',
#   120),
#  ('XP_010634625.1 PREDICTED: prolactin [Fukomys damarensis]', 121),
#  ('XP_011456301.1 PREDICTED: chymotrypsin BI [Crassostrea gigas]', 121),
#  ('XP_018924665.1 PREDICTED: chymotrypsin A-like [Cyprinus carpio]', 121),
#  ('XP_018594343.1 PREDICTED: chymotrypsin A-like [Scleropages formosus]', 121),
#  ('XP_005499985.1 PREDICTED: prolactin [Columba livia]', 121),
#  ('XP_019757535.1 PREDICTED: chymotrypsin BI-like [Dendroctonus ponderosae]',
#   123),
#  ('XP_014100936.1 PREDICTED: chymotrypsin BI-like, partial [Bactrocera oleae]',
#   123),
#  ('XP_017048427.1 PREDICTED: chymotrypsin BI-like [Drosophila ficusphila]',
#   124),
#  ('XP_014101585.1 PREDICTED: chymotrypsin BI-like, partial [Bactrocera oleae]',
#   124),
#  ('XP_019133739.1 PREDICTED: chymotrypsin B-like, partial [Larimichthys crocea]',
#   124),
#  ('XP_017588646.1 PREDICTED: prolactin [Corvus brachyrhynchos]', 124),
#  ('XP_018011405.1 PREDICTED: chymotrypsin BII-like [Hyalella azteca]', 125),
#  ('XP_019280769.1 PREDICTED: prolactin [Panthera pardus]', 125),
#  ('XP_018933928.1 PREDICTED: chymotrypsin B-like [Cyprinus carpio]', 125),
#  ('XP_018950830.1 PREDICTED: chymotrypsin A-like [Cyprinus carpio]', 126),
#  ('XP_010634608.1 PREDICTED: prolactin isoform X1 [Fukomys damarensis]', 126),
#  ('XP_010634611.1 PREDICTED: prolactin isoform X1 [Fukomys damarensis]', 126),
#  ('XP_014523088.1 PREDICTED: chymotrypsin inhibitor 3-like [Vigna radiata var. radiata]',
#   126),
#  ('XP_010634610.1 PREDICTED: prolactin isoform X1 [Fukomys damarensis]', 126),
#  ('XP_016352619.1 PREDICTED: chymotrypsin A-like [Sinocyclocheilus anshuiensis]',
#   127),
#  ('XP_019757536.1 PREDICTED: chymotrypsin BII-like, partial [Dendroctonus ponderosae]',
#   127),
#  ('XP_016427304.1 PREDICTED: chymotrypsin A-like, partial [Sinocyclocheilus rhinocerous]',
#   127),
#  ('XP_017491684.1 PREDICTED: chymotrypsin BI-like, partial [Rhagoletis zephyria]',
#   127),
#  ('XP_014493060.1 PREDICTED: chymotrypsin inhibitor 3-like [Vigna radiata var. radiata]',
#   127),
#  ('XP_014523761.1 PREDICTED: chymotrypsin inhibitor 3-like [Vigna radiata var. radiata]',
#   127),
#  ('XP_014523090.1 PREDICTED: chymotrypsin inhibitor 3-like [Vigna radiata var. radiata]',
#   127),
#  ('XP_014681117.1 PREDICTED: chymotrypsin B-like [Priapulus caudatus]', 127),
#  ('XP_005183429.1 PREDICTED: chymotrypsin BI-like, partial [Musca domestica]',
#   127),
#  ('XP_014523087.1 PREDICTED: chymotrypsin inhibitor 3-like [Vigna radiata var. radiata]',
#   127),
#  ('XP_017417821.1 PREDICTED: chymotrypsin inhibitor 3-like [Vigna angularis]',
#   127),
#  ('XP_016335231.1 PREDICTED: chymotrypsin B-like [Sinocyclocheilus anshuiensis]',
#   128),
#  ('XP_018950829.1 PREDICTED: chymotrypsin A-like [Cyprinus carpio]', 128),
#  ('XP_008199319.1 PREDICTED: chymotrypsin BII isoform X2 [Tribolium castaneum]',
#   128),
#  ('XP_016427151.1 PREDICTED: chymotrypsin A-like [Sinocyclocheilus rhinocerous]',
#   128),
#  ('XP_014522569.1 PREDICTED: chymotrypsin inhibitor ECI-like, partial [Vigna radiata var. radiata]',
#   128),
#  ('XP_018950828.1 PREDICTED: chymotrypsin A-like [Cyprinus carpio]', 128),
#  ('XP_019894518.1 PREDICTED: chymotrypsin BI-like [Musca domestica]', 129),
#  ('XP_010693985.1 PREDICTED: chymotrypsin inhibitor 3 [Beta vulgaris subsp. vulgaris]',
#   129),
#  ('XP_014511580.1 PREDICTED: chymotrypsin inhibitor 3-like [Vigna radiata var. radiata]',
#   129),
#  ('XP_019879901.1 PREDICTED: chymotrypsin BII-like, partial [Aethina tumida]',
#   129),
#  ('XP_017484934.1 PREDICTED: chymotrypsin BI-like [Rhagoletis zephyria]', 129),
#  ('XP_014511581.1 PREDICTED: chymotrypsin inhibitor 3-like [Vigna radiata var. radiata]',
#   129),
#  ('XP_018967813.1 PREDICTED: chymotrypsin A-like [Cyprinus carpio]', 129),
#  ('XP_014492087.1 PREDICTED: chymotrypsin inhibitor 3-like [Vigna radiata var. radiata]',
#   129),
#  ('XP_013140376.1 PREDICTED: chymotrypsin BI-like isoform X3 [Papilio polytes]',
#   130),
#  ('XP_016103835.1 PREDICTED: chymotrypsin A-like [Sinocyclocheilus grahami]',
#   130),
#  ('XP_019215462.1 PREDICTED: chymotrypsin B, partial [Oreochromis niloticus]',
#   130),
#  ('XP_016408429.1 PREDICTED: chymotrypsin A-like [Sinocyclocheilus rhinocerous]',
#   130),
#  ('XP_016970959.1 PREDICTED: chymotrypsin BI-like, partial [Drosophila rhopaloa]',
#   131),
#  ('XP_014203901.1 PREDICTED: chymotrypsin A-like [Copidosoma floridanum]',
#   131),
#  ('XP_014511584.1 PREDICTED: chymotrypsin inhibitor 3-like [Vigna radiata var. radiata]',
#   132),
#  ('XP_014651348.1 PREDICTED: chymotrypsin B-like [Ceratotherium simum simum]',
#   132),
#  ('XP_018967814.1 PREDICTED: chymotrypsin A-like [Cyprinus carpio]', 132),
#  ('XP_018080028.1 PREDICTED: chymotrypsin like elastase family member 3B L homeolog isoform X2 [Xenopus laevis]',
#   132),
#  ('XP_018562733.1 PREDICTED: chymotrypsin BII-like [Anoplophora glabripennis]',
#   133),
#  ('XP_008927937.1 PREDICTED: prolactin [Manacus vitellinus]', 133),
#  ('XP_006002467.1 PREDICTED: chymotrypsin A-like, partial [Latimeria chalumnae]',
#   134),
#  ('XP_018012629.1 PREDICTED: chymotrypsin A-like [Hyalella azteca]', 134),
#  ('XP_020182336.1 chymotrypsin inhibitor WCI [Aegilops tauschii subsp. tauschii]',
#   134),
#  ('XP_004640235.1 PREDICTED: prolactin [Octodon degus]', 135),
#  ('XP_015882753.1 PREDICTED: Bowman-Birk type seed trypsin and chymotrypsin inhibitor-like [Ziziphus jujuba]',
#   135),
#  ('XP_015882752.1 PREDICTED: Bowman-Birk type seed trypsin and chymotrypsin inhibitor-like [Ziziphus jujuba]',
#   135),
#  ('XP_018080027.1 PREDICTED: chymotrypsin like elastase family member 3B L homeolog isoform X1 [Xenopus laevis]',
#   136),
#  ('XP_019628532.1 PREDICTED: chymotrypsin A-like [Branchiostoma belcheri]',
#   137),
#  ('XP_017484935.1 PREDICTED: chymotrypsin BI-like, partial [Rhagoletis zephyria]',
#   137),
#  ('XP_018924696.1 PREDICTED: LOW QUALITY PROTEIN: chymotrypsin A-like [Cyprinus carpio]',
#   137),
#  ('XP_017012421.1 PREDICTED: chymotrypsin isoform X2 [Drosophila takahashii]',
#   137),
#  ('XP_016119896.1 PREDICTED: chymotrypsin A-like [Sinocyclocheilus grahami]',
#   137),
#  ('XP_019879948.1 PREDICTED: chymotrypsin BI-like [Aethina tumida]', 138),
#  ('XP_014784832.1 PREDICTED: chymotrypsin A-like [Octopus bimaculoides]', 138),
#  ('XP_019874616.1 PREDICTED: chymotrypsin BI-like [Aethina tumida]', 138),
#  ('XP_015771051.1 PREDICTED: chymotrypsin B-like [Acropora digitifera]', 139),
#  ('XP_015225035.1 PREDICTED: chymotrypsin A-like [Cyprinodon variegatus]',
#   139),
#  ('XP_020333481.1 chymotrypsin A-like, partial [Oncorhynchus kisutch]', 140),
#  ('XP_016975228.1 PREDICTED: chymotrypsin BI-like, partial [Drosophila rhopaloa]',
#   140),
#  ('XP_006367785.1 PREDICTED: chymotrypsin inhibitor I, A, B and C subunits-like [Solanum tuberosum]',
#   141),
#  ('XP_007246951.1 PREDICTED: chymotrypsin A-like isoform X1 [Astyanax mexicanus]',
#   142),
#  ('XP_016955872.1 PREDICTED: chymotrypsin [Drosophila biarmipes]', 142),
#  ('NP_997783.1 chymotrypsin B1 precursor [Danio rerio]', 142),
#  ('XP_008782781.1 PREDICTED: chymotrypsin inhibitor I, A, B and C subunits [Phoenix dactylifera]',
#   142),
#  ('XP_005726388.1 PREDICTED: LOW QUALITY PROTEIN: chymotrypsin B-like [Pundamilia nyererei]',
#   142),
#  ('XP_016161278.1 PREDICTED: chymotrypsin A-like, partial [Ficedula albicollis]',
#   143),
#  ('XP_012776340.1 PREDICTED: chymotrypsin A-like [Maylandia zebra]', 143),
#  ('XP_018548300.1 PREDICTED: chymotrypsin A-like [Lates calcarifer]', 143),
#  ('XP_015460707.1 PREDICTED: chymotrypsin A-like isoform X2 [Astyanax mexicanus]',
#   143),
#  ('XP_018308078.1 PREDICTED: chymotrypsin inhibitor [Trachymyrmex zeteki]',
#   143),
#  ('XP_018570818.1 PREDICTED: chymotrypsin BII-like [Anoplophora glabripennis]',
#   143),
#  ('XP_005534680.1 PREDICTED: chymotrypsin A-like, partial [Pseudopodoces humilis]',
#   143),
#  ('XP_019628320.1 PREDICTED: chymotrypsin A-like [Branchiostoma belcheri]',
#   143),
#  ('XP_968239.2 PREDICTED: chymotrypsin BI [Tribolium castaneum]', 143),
#  ('XP_008308381.1 PREDICTED: chymotrypsin A-like [Cynoglossus semilaevis]',
#   144),
#  ('XP_017418121.1 PREDICTED: chymotrypsin inhibitor 3-like [Vigna angularis]',
#   144),
#  ('XP_016085321.1 PREDICTED: chymotrypsin A-like [Sinocyclocheilus grahami]',
#   144),
#  ('XP_016103872.1 PREDICTED: chymotrypsin A-like [Sinocyclocheilus grahami]',
#   144),
#  ('XP_015223928.1 PREDICTED: LOW QUALITY PROTEIN: chymotrypsin B-like [Lepisosteus oculatus]',
#   144),
#  ('XP_001810160.1 PREDICTED: chymotrypsin BII isoform X1 [Tribolium castaneum]',
#   144),
#  ('XP_016934811.1 PREDICTED: chymotrypsin B [Drosophila suzukii]', 144),
#  ('XP_018594374.1 PREDICTED: chymotrypsin B-like [Scleropages formosus]', 145),
#  ('XP_017340091.1 PREDICTED: chymotrypsin A-like [Ictalurus punctatus]', 145),
#  ('XP_013183860.1 PREDICTED: chymotrypsin BII-like [Amyelois transitella]',
#   145),
#  ('XP_007246948.1 PREDICTED: chymotrypsin A-like [Astyanax mexicanus]', 145),
#  ('XP_015435619.1 PREDICTED: chymotrypsin inhibitor-like [Dufourea novaeangliae]',
#   145),
#  ('XP_017783471.1 PREDICTED: chymotrypsin BII-like [Nicrophorus vespilloides]',
#   145),
#  ('XP_016427303.1 PREDICTED: LOW QUALITY PROTEIN: chymotrypsin A-like [Sinocyclocheilus rhinocerous]',
#   145),
#  ('XP_020333480.1 LOW QUALITY PROTEIN: chymotrypsin A-like [Oncorhynchus kisutch]',
#   145),
#  ('XP_015808810.1 PREDICTED: chymotrypsin A-like [Nothobranchius furzeri]',
#   145),
#  ('XP_013883985.1 PREDICTED: chymotrypsin A-like [Austrofundulus limnaeus]',
#   145),
#  ('XP_014038153.1 PREDICTED: chymotrypsin A-like [Salmo salar]', 145),
#  ('NP_001191247.1 prolactin receptor isoform 5 precursor [Homo sapiens]', 145),
#  ('XP_010894464.1 PREDICTED: chymotrypsin A [Esox lucius]', 145),
#  ('XP_019748828.1 PREDICTED: chymotrypsin B-like [Hippocampus comes]', 146),
#  ('XP_017561630.1 PREDICTED: chymotrypsin B-like [Pygocentrus nattereri]',
#   146),
#  ('XP_019527425.1 PREDICTED: chymotrypsin inhibitor-like [Aedes albopictus]',
#   146),
#  ('XP_014032286.1 PREDICTED: chymotrypsin A-like [Salmo salar]', 146),
#  ('XP_016352621.1 PREDICTED: chymotrypsin A-like [Sinocyclocheilus anshuiensis]',
#   146),
#  ('XP_019879947.1 PREDICTED: chymotrypsin BI-like [Aethina tumida]', 146),
#  ('XP_016085319.1 PREDICTED: chymotrypsin A-like [Sinocyclocheilus grahami]',
#   146),
#  ('XP_018594372.1 PREDICTED: chymotrypsin A-like [Scleropages formosus]', 146),
#  ('XP_005929268.2 PREDICTED: LOW QUALITY PROTEIN: chymotrypsin B-like [Haplochromis burtoni]',
#   146),
#  ('XP_008308425.2 PREDICTED: chymotrypsin B-like isoform X3 [Cynoglossus semilaevis]',
#   147),
#  ('XP_016300591.1 PREDICTED: chymotrypsin A-like [Sinocyclocheilus anshuiensis]',
#   147),
#  ('XP_016408440.1 PREDICTED: chymotrypsin B-like [Sinocyclocheilus rhinocerous]',
#   147),
#  ('XP_018924664.1 PREDICTED: chymotrypsin B-like [Cyprinus carpio]', 147),
#  ('XP_018115407.1 PREDICTED: chymotrypsin B-like [Xenopus laevis]', 147),
#  ('XP_017030191.1 PREDICTED: chymotrypsin inhibitor [Drosophila kikkawai]',
#   147),
#  ('XP_002935402.2 PREDICTED: chymotrypsin B-like [Xenopus tropicalis]', 147),
#  ('XP_016427169.1 PREDICTED: chymotrypsin B-like [Sinocyclocheilus rhinocerous]',
#   147),
#  ('XP_016085293.1 PREDICTED: chymotrypsin B-like [Sinocyclocheilus grahami]',
#   147),
#  ('XP_015174768.1 PREDICTED: chymotrypsin inhibitor-like isoform X1 [Polistes dominula]',
#   147),
#  ('NP_001015686.1 chymotrypsin B1 precursor [Xenopus tropicalis]', 147),
#  ('XP_016103834.1 PREDICTED: chymotrypsin B-like [Sinocyclocheilus grahami]',
#   147),
#  ('XP_019935355.1 PREDICTED: chymotrypsin B-like [Paralichthys olivaceus]',
#   147),
#  ('XP_005814935.1 PREDICTED: chymotrypsin A-like [Xiphophorus maculatus]',
#   147),
#  ('XP_016352618.1 PREDICTED: chymotrypsin B-like [Sinocyclocheilus anshuiensis]',
#   147),
#  ('XP_013909160.1 PREDICTED: chymotrypsin B-like [Thamnophis sirtalis]', 147),
#  ('XP_016408397.1 PREDICTED: chymotrypsin A-like [Sinocyclocheilus rhinocerous]',
#   147),
#  ('XP_019628587.1 PREDICTED: chymotrypsin B-like [Branchiostoma belcheri]',
#   147),
#  ('XP_004539899.1 PREDICTED: LOW QUALITY PROTEIN: chymotrypsin B-like [Maylandia zebra]',
#   147),
#  ('XP_019528752.1 PREDICTED: chymotrypsin inhibitor-like [Aedes albopictus]',
#   148),
#  ('XP_017153484.1 PREDICTED: chymotrypsin inhibitor SCI-I [Drosophila miranda]',
#   148),
#  ('XP_014882115.1 PREDICTED: chymotrypsin A-like [Poecilia latipinna]', 148),
#  ('XP_017561631.1 PREDICTED: chymotrypsin A-like [Pygocentrus nattereri]',
#   148),
#  ('XP_015518650.1 PREDICTED: chymotrypsin inhibitor-like [Neodiprion lecontei]',
#   148),
#  ('XP_016528321.1 PREDICTED: chymotrypsin A-like isoform X2 [Poecilia formosa]',
#   148),
#  ('XP_017491409.1 PREDICTED: chymotrypsin inhibitor [Rhagoletis zephyria]',
#   148),
#  ('XP_016417739.1 PREDICTED: chymotrypsin B-like [Sinocyclocheilus rhinocerous]',
#   148),
#  ('XP_005514623.1 PREDICTED: chymotrypsin inhibitor isoform X3 [Columba livia]',
#   148),
#  ('XP_017860831.1 PREDICTED: chymotrypsin inhibitor SCI-I-like [Drosophila arizonae]',
#   148),
#  ('XP_016528320.1 PREDICTED: chymotrypsin A-like isoform X2 [Poecilia formosa]',
#   148),
#  ('XP_018548298.1 PREDICTED: chymotrypsin B [Lates calcarifer]', 148),
#  ('XP_010894463.1 PREDICTED: chymotrypsin B [Esox lucius]', 148),
#  ('XP_019528753.1 PREDICTED: chymotrypsin inhibitor [Aedes albopictus]', 148),
#  ('XP_016528318.1 PREDICTED: chymotrypsin A-like isoform X2 [Poecilia formosa]',
#   148),
#  ('XP_015435593.1 PREDICTED: chymotrypsin inhibitor-like, partial [Dufourea novaeangliae]',
#   148),
#  ('NP_001008077.1 chymotrypsin C precursor [Xenopus tropicalis]', 148),
#  ('XP_017006605.1 PREDICTED: chymotrypsin inhibitor [Drosophila takahashii]',
#   148),
#  ('XP_004913565.1 PREDICTED: chymotrypsin B-like [Xenopus tropicalis]', 148),
#  ('XP_016528319.1 PREDICTED: chymotrypsin A-like isoform X2 [Poecilia formosa]',
#   148),
#  ('XP_019527349.1 PREDICTED: chymotrypsin inhibitor-like [Aedes albopictus]',
#   148),
#  ('XP_015113176.1 PREDICTED: chymotrypsin inhibitor-like [Diachasma alloeum]',
#   148),
#  ('XP_008308134.1 PREDICTED: chymotrypsin B-like [Cynoglossus semilaevis]',
#   149),
#  ('XP_011200990.1 PREDICTED: chymotrypsin inhibitor-like [Bactrocera dorsalis]',
#   149),
#  ('XP_015808724.1 PREDICTED: chymotrypsin B-like [Nothobranchius furzeri]',
#   149),
#  ('XP_002944677.2 PREDICTED: chymotrypsin B [Xenopus tropicalis]', 149),
#  ('XP_014368262.1 PREDICTED: chymotrypsin inhibitor-like [Papilio machaon]',
#   149),
#  ('XP_014099719.1 PREDICTED: chymotrypsin inhibitor-like [Bactrocera oleae]',
#   149),
#  ('XP_016845877.1 PREDICTED: chymotrypsin inhibitor-like [Nasonia vitripennis]',
#   149),
#  ('XP_015174769.1 PREDICTED: chymotrypsin inhibitor-like isoform X2 [Polistes dominula]',
#   149),
#  ('XP_017761192.1 PREDICTED: chymotrypsin inhibitor-like isoform X1 [Eufriesea mexicana]',
#   149),
#  ('NP_001087140.1 chymotrypsin like elastase family member 3B L homeolog precursor [Xenopus laevis]',
#   149),
#  ('XP_010885737.1 PREDICTED: chymotrypsin B-like [Esox lucius]', 149),
#  ('XP_018789880.1 PREDICTED: chymotrypsin inhibitor-like [Bactrocera latifrons]',
#   149),
#  ('XP_005182640.1 PREDICTED: chymotrypsin inhibitor SCI-III [Musca domestica]',
#   149),
#  ('XP_016888039.1 PREDICTED: chymotrypsin B-like isoform X2 [Cynoglossus semilaevis]',
#   150),
#  ('XP_018789871.1 PREDICTED: chymotrypsin inhibitor [Bactrocera latifrons]',
#   150),
#  ('XP_008308388.1 PREDICTED: chymotrypsin B-like [Cynoglossus semilaevis]',
#   150),
#  ('NP_001082222.1 chymotrypsin like elastase family member 1 precursor [Xenopus laevis]',
#   150),
#  ('XP_019527417.1 PREDICTED: chymotrypsin inhibitor-like [Aedes albopictus]',
#   150),
#  ('XP_017067596.1 PREDICTED: chymotrypsin inhibitor [Drosophila eugracilis]',
#   150),
#  ('XP_017100090.1 PREDICTED: chymotrypsin BI-like [Drosophila bipectinata]',
#   150),
#  ('NP_001011493.1 chymotrypsin like elastase family member 1 precursor [Xenopus tropicalis]',
#   150),
#  ('XP_007246950.1 PREDICTED: chymotrypsin B-like [Astyanax mexicanus]', 150),
#  ('XP_011137141.1 PREDICTED: chymotrypsin inhibitor-like [Harpegnathos saltator]',
#   150),
#  ('XP_013177788.1 PREDICTED: chymotrypsin inhibitor-like [Papilio xuthus]',
#   150),
#  ('XP_008308382.1 PREDICTED: chymotrypsin B-like isoform X1 [Cynoglossus semilaevis]',
#   150),
#  ('NP_001085458.1 chymotrypsin C L homeolog precursor [Xenopus laevis]', 150),
#  ('XP_020370423.1 chymotrypsin B-like [Rhincodon typus]', 150),
#  ('XP_016888040.1 PREDICTED: chymotrypsin B-like [Cynoglossus semilaevis]',
#   150),
#  ('XP_012996143.1 PREDICTED: chymotrypsin inhibitor-like [Esox lucius]', 151),
#  ('XP_008215341.1 PREDICTED: chymotrypsin inhibitor-like [Nasonia vitripennis]',
#   151),
#  ('XP_017293037.1 PREDICTED: LOW QUALITY PROTEIN: chymotrypsin A-like [Kryptolebias marmoratus]',
#   151),
#  ('XP_015591763.1 PREDICTED: chymotrypsin inhibitor-like [Cephus cinctus]',
#   151),
#  ('NP_001134565.1 Chymotrypsin B precursor [Salmo salar]', 151),
#  ('XP_014064148.1 PREDICTED: chymotrypsin B-like [Salmo salar]', 151),
#  ('XP_017881584.1 PREDICTED: chymotrypsin inhibitor-like [Ceratina calcarata]',
#   151),
#  ('XP_014039723.1 PREDICTED: chymotrypsin B-like [Salmo salar]', 151),
#  ('XP_014099721.1 PREDICTED: chymotrypsin inhibitor-like [Bactrocera oleae]',
#   151),
#  ('NP_001037291.1 chymotrypsin inhibitor fb precursor [Bombyx mori]', 151),
#  ('XP_001607369.1 PREDICTED: chymotrypsin inhibitor-like [Nasonia vitripennis]',
#   151),
#  ('XP_015924666.1 PREDICTED: chymotrypsin inhibitor-like [Parasteatoda tepidariorum]',
#   151),
#  ('NP_001036877.1 chymotrypsin inhibitor precursor [Bombyx mori]', 151),
#  ('XP_973000.1 PREDICTED: chymotrypsin BI [Tribolium castaneum]', 151),
#  ('XP_014009280.1 PREDICTED: chymotrypsin B-like [Salmo salar]', 151),
#  ('XP_019528755.1 PREDICTED: chymotrypsin inhibitor [Aedes albopictus]', 151),
#  ('XP_017786988.1 PREDICTED: chymotrypsin inhibitor-like [Nicrophorus vespilloides]',
#   151),
#  ('XP_016359098.1 PREDICTED: chymotrypsin B-like [Sinocyclocheilus anshuiensis]',
#   151),
#  ('XP_019890240.1 PREDICTED: chymotrypsin inhibitor-like [Musca domestica]',
#   151),
#  ('XP_008196578.1 PREDICTED: chymotrypsin BI [Tribolium castaneum]', 151),
#  ('XP_019845214.1 PREDICTED: chymotrypsin inhibitor-like [Bactrocera dorsalis]',
#   151),
#  ('XP_017489901.1 PREDICTED: chymotrypsin inhibitor SCI-II-like [Rhagoletis zephyria]',
#   151),
#  ('XP_015248332.1 PREDICTED: chymotrypsin B-like [Cyprinodon variegatus]',
#   152),
#  ('XP_015923461.1 PREDICTED: chymotrypsin inhibitor-like isoform X1 [Parasteatoda tepidariorum]',
#   152),
#  ('XP_017889703.1 PREDICTED: chymotrypsin inhibitor-like [Ceratina calcarata]',
#   152),
#  ('XP_008400929.1 PREDICTED: chymotrypsin A-like [Poecilia reticulata]', 152),
#  ('XP_017038392.1 PREDICTED: chymotrypsin inhibitor SCI-III [Drosophila kikkawai]',
#   152),
#  ('XP_019714213.1 PREDICTED: chymotrypsin A-like, partial [Hippocampus comes]',
#   152),
#  ('XP_015903610.1 PREDICTED: chymotrypsin inhibitor-like [Parasteatoda tepidariorum]',
#   152),
#  ('XP_007554885.1 PREDICTED: chymotrypsin A-like isoform X1 [Poecilia formosa]',
#   152),
#  ('NP_001119737.1 chymotrypsin inhibitor SCI-III precursor [Bombyx mori]',
#   152),
#  ('XP_015912476.1 PREDICTED: chymotrypsin inhibitor-like [Parasteatoda tepidariorum]',
#   152),
#  ('XP_017761208.1 PREDICTED: chymotrypsin inhibitor-like [Eufriesea mexicana]',
#   152),
#  ('XP_014835033.1 PREDICTED: chymotrypsin A-like [Poecilia mexicana]', 152),
#  ('XP_016909751.1 PREDICTED: chymotrypsin inhibitor-like [Apis cerana]', 152),
#  ('XP_001120999.2 PREDICTED: chymotrypsin inhibitor [Apis mellifera]', 152),
#  ('XP_020325127.1 chymotrypsin B-like [Oncorhynchus kisutch]', 152),
#  ('XP_005177634.1 PREDICTED: chymotrypsin inhibitor [Musca domestica]', 153),
#  ('XP_018789894.1 PREDICTED: chymotrypsin inhibitor-like [Bactrocera latifrons]',
#   153),
#  ('XP_001121077.2 PREDICTED: chymotrypsin inhibitor-like isoform X1 [Apis mellifera]',
#   153),
#  ('XP_008215340.1 PREDICTED: chymotrypsin inhibitor-like [Nasonia vitripennis]',
#   153),
#  ('XP_016915256.1 PREDICTED: chymotrypsin inhibitor-like [Apis cerana]', 153),
#  ('XP_017791802.1 PREDICTED: chymotrypsin inhibitor-like [Habropoda laboriosa]',
#   153),
#  ('XP_003423856.1 PREDICTED: chymotrypsin inhibitor [Nasonia vitripennis]',
#   153),
#  ('XP_019696294.1 PREDICTED: chymotrypsin inhibitor-like [Harpegnathos saltator]',
#   153),
#  ('XP_019528808.1 PREDICTED: chymotrypsin inhibitor-like [Aedes albopictus]',
#   153),
#  ('XP_011200992.1 PREDICTED: chymotrypsin inhibitor-like [Bactrocera dorsalis]',
#   153),
#  ('XP_017786987.1 PREDICTED: chymotrypsin inhibitor-like isoform X2 [Nicrophorus vespilloides]',
#   153),
#  ('XP_017110585.1 PREDICTED: chymotrypsin inhibitor SCI-III [Drosophila elegans]',
#   153),
#  ('XP_014099718.1 PREDICTED: chymotrypsin inhibitor-like [Bactrocera oleae]',
#   153),
#  ('XP_017889422.1 PREDICTED: chymotrypsin inhibitor-like [Ceratina calcarata]',
#   153),
#  ('XP_008555210.1 PREDICTED: chymotrypsin inhibitor [Microplitis demolitor]',
#   153),
#  ('XP_005177635.2 PREDICTED: chymotrypsin inhibitor-like [Musca domestica]',
#   153),
#  ('XP_016909871.1 PREDICTED: chymotrypsin inhibitor-like [Apis cerana]', 153),
#  ('XP_017761193.1 PREDICTED: chymotrypsin inhibitor-like isoform X2 [Eufriesea mexicana]',
#   153),
#  ('XP_018789908.1 PREDICTED: chymotrypsin inhibitor-like [Bactrocera latifrons]',
#   153),
#  ('XP_003250085.1 PREDICTED: chymotrypsin inhibitor [Apis mellifera]', 153),
#  ('XP_016123516.1 PREDICTED: chymotrypsin B-like [Sinocyclocheilus grahami]',
#   153),
#  ('XP_016982857.1 PREDICTED: chymotrypsin inhibitor SCI-III [Drosophila rhopaloa]',
#   153),
#  ('XP_017889702.1 PREDICTED: chymotrypsin inhibitor-like [Ceratina calcarata]',
#   153),
#  ('XP_003252042.1 PREDICTED: chymotrypsin inhibitor-like [Apis mellifera]',
#   153),
#  ('XP_015912480.1 PREDICTED: chymotrypsin inhibitor-like [Parasteatoda tepidariorum]',
#   154),
#  ('XP_016956542.1 PREDICTED: chymotrypsin inhibitor SCI-III [Drosophila biarmipes]',
#   154),
#  ('XP_019696291.1 PREDICTED: chymotrypsin inhibitor-like isoform X2 [Harpegnathos saltator]',
#   154),
#  ('NP_001119717.1 chymotrypsin inhibitor SCI-II precursor [Bombyx mori]', 154),
#  ('XP_018701376.1 chymotrypsin B1 [Isaria fumosorosea ARSEF 2679]', 154),
#  ('XP_017791822.1 PREDICTED: chymotrypsin inhibitor-like [Habropoda laboriosa]',
#   154),
#  ('XP_017151268.1 PREDICTED: chymotrypsin inhibitor SCI-II-like [Drosophila miranda]',
#   154),
#  ('XP_017786986.1 PREDICTED: chymotrypsin inhibitor-like isoform X1 [Nicrophorus vespilloides]',
#   154),
#  ('XP_019696292.1 PREDICTED: chymotrypsin inhibitor-like isoform X3 [Harpegnathos saltator]',
#   154),
#  ('XP_014604014.1 PREDICTED: chymotrypsin inhibitor [Polistes canadensis]',
#   154),
#  ('XP_017110594.1 PREDICTED: chymotrypsin inhibitor SCI-I [Drosophila elegans]',
#   154),
#  ('XP_014599121.1 PREDICTED: chymotrypsin inhibitor-like [Polistes canadensis]',
#   154),
#  ('XP_019527419.1 PREDICTED: chymotrypsin inhibitor-like [Aedes albopictus]',
#   154),
#  ('XP_016925147.1 PREDICTED: chymotrypsin inhibitor SCI-III [Drosophila suzukii]',
#   154),
#  ('XP_014475488.1 PREDICTED: chymotrypsin inhibitor-like isoform X2 [Dinoponera quadriceps]',
#   154),
#  ('XP_017889424.1 PREDICTED: chymotrypsin inhibitor-like [Ceratina calcarata]',
#   154),
#  ('XP_010634624.1 PREDICTED: prolactin [Fukomys damarensis]', 154),
#  ('XP_001607538.1 PREDICTED: chymotrypsin inhibitor-like [Nasonia vitripennis]',
#   154),
#  ('XP_017786995.1 PREDICTED: chymotrypsin inhibitor-like isoform X1 [Nicrophorus vespilloides]',
#   154),
#  ('XP_020288981.1 chymotrypsin inhibitor-like [Pseudomyrmex gracilis]', 154),
#  ('XP_017889704.1 PREDICTED: chymotrypsin inhibitor-like [Ceratina calcarata]',
#   154),
#  ('XP_014475516.1 PREDICTED: chymotrypsin inhibitor-like [Dinoponera quadriceps]',
#   154),
#  ('XP_017075789.1 PREDICTED: chymotrypsin inhibitor SCI-III [Drosophila eugracilis]',
#   154),
#  ('XP_970603.1 PREDICTED: chymotrypsin BI [Tribolium castaneum]', 154),
#  ('XP_006563420.1 PREDICTED: chymotrypsin inhibitor-like isoform X2 [Apis mellifera]',
#   154),
#  ('XP_017075056.1 PREDICTED: chymotrypsin inhibitor SCI-III [Drosophila eugracilis]',
#   155),
#  ('XP_014475515.1 PREDICTED: chymotrypsin inhibitor-like [Dinoponera quadriceps]',
#   155),
#  ('XP_017786998.1 PREDICTED: chymotrypsin inhibitor-like [Nicrophorus vespilloides]',
#   155),
#  ('XP_017007127.1 PREDICTED: chymotrypsin inhibitor SCI-III [Drosophila takahashii]',
#   155),
#  ('XP_008190813.1 PREDICTED: chymotrypsin inhibitor-like [Tribolium castaneum]',
#   155),
#  ('XP_014475364.1 PREDICTED: chymotrypsin inhibitor-like [Dinoponera quadriceps]',
#   155),
#  ('XP_016956930.1 PREDICTED: chymotrypsin inhibitor SCI-II [Drosophila biarmipes]',
#   155),
#  ('XP_015596271.1 PREDICTED: chymotrypsin inhibitor-like isoform X1 [Cephus cinctus]',
#   155),
#  ('XP_017787033.1 PREDICTED: chymotrypsin inhibitor-like [Nicrophorus vespilloides]',
#   155),
#  ('XP_017890188.1 PREDICTED: chymotrypsin inhibitor-like [Ceratina calcarata]',
#   155),
#  ('XP_017007158.1 PREDICTED: chymotrypsin inhibitor SCI-II [Drosophila takahashii]',
#   155),
#  ('XP_014099720.1 PREDICTED: chymotrypsin inhibitor-like [Bactrocera oleae]',
#   155),
#  ('XP_017110576.1 PREDICTED: chymotrypsin inhibitor SCI-II [Drosophila elegans]',
#   155),
#  ('XP_017857335.1 PREDICTED: chymotrypsin inhibitor SCI-II-like [Drosophila arizonae]',
#   155),
#  ('XP_017786997.1 PREDICTED: chymotrypsin inhibitor-like [Nicrophorus vespilloides]',
#   155),
#  ('NP_001011426.1 chymotrypsin like elastase family member 3A precursor [Xenopus tropicalis]',
#   155),
#  ('XP_015174610.1 PREDICTED: chymotrypsin inhibitor [Polistes dominula]', 155),
#  ('XP_017786996.1 PREDICTED: chymotrypsin inhibitor-like isoform X2 [Nicrophorus vespilloides]',
#   155),
#  ('XP_011266508.1 PREDICTED: chymotrypsin inhibitor [Camponotus floridanus]',
#   155),
#  ('XP_017791823.1 PREDICTED: chymotrypsin inhibitor-like [Habropoda laboriosa]',
#   155),
#  ('XP_015625094.1 PREDICTED: chymotrypsin inhibitor-like [Oryza sativa Japonica Group]',
#   155),
#  ('XP_017097722.1 PREDICTED: chymotrypsin inhibitor SCI-III [Drosophila bipectinata]',
#   155),
#  ('XP_018496173.1 PREDICTED: chymotrypsin B [Galendromus occidentalis]', 156),
#  ('XP_014599123.1 PREDICTED: chymotrypsin inhibitor-like [Polistes canadensis]',
#   156),
#  ('XP_011137142.1 PREDICTED: chymotrypsin inhibitor-like [Harpegnathos saltator]',
#   156),
#  ('XP_015596273.1 PREDICTED: chymotrypsin inhibitor [Cephus cinctus]', 156),
#  ('XP_011337783.1 PREDICTED: chymotrypsin inhibitor-like [Cerapachys biroi]',
#   156),
#  ('XP_018370168.1 PREDICTED: chymotrypsin inhibitor-like [Trachymyrmex cornetzi]',
#   156),
#  ('XP_017791824.1 PREDICTED: chymotrypsin inhibitor-like [Habropoda laboriosa]',
#   156),
#  ('XP_017153878.1 PREDICTED: chymotrypsin inhibitor SCI-III-like [Drosophila miranda]',
#   156),
#  ('XP_018362656.1 PREDICTED: chymotrypsin inhibitor-like [Trachymyrmex cornetzi]',
#   156),
#  ('XP_017110572.1 PREDICTED: chymotrypsin inhibitor SCI-III-like [Drosophila elegans]',
#   156),
#  ('XP_017104464.1 PREDICTED: chymotrypsin inhibitor-like [Drosophila bipectinata]',
#   156),
#  ('XP_011266509.1 PREDICTED: chymotrypsin inhibitor-like [Camponotus floridanus]',
#   156),
#  ('XP_018308077.1 PREDICTED: chymotrypsin inhibitor [Trachymyrmex zeteki]',
#   157),
#  ('XP_016944901.1 PREDICTED: chymotrypsin inhibitor SCI-III-like [Drosophila suzukii]',
#   157),
#  ('XP_018341684.1 PREDICTED: chymotrypsin inhibitor-like [Trachymyrmex septentrionalis]',
#   157),
#  ('XP_015174770.1 PREDICTED: chymotrypsin inhibitor-like isoform X3 [Polistes dominula]',
#   157),
#  ('XP_017888379.1 PREDICTED: chymotrypsin inhibitor-like [Ceratina calcarata]',
#   157),
#  ('XP_015111867.1 PREDICTED: chymotrypsin inhibitor-like [Diachasma alloeum]',
#   157),
#  ('XP_011337784.1 PREDICTED: chymotrypsin inhibitor [Cerapachys biroi]', 157),
#  ('XP_020288964.1 chymotrypsin inhibitor-like [Pseudomyrmex gracilis]', 157),
#  ('XP_015596272.1 PREDICTED: chymotrypsin inhibitor-like isoform X2 [Cephus cinctus]',
#   157),
#  ('XP_015435639.1 PREDICTED: chymotrypsin inhibitor-like [Dufourea novaeangliae]',
#   157),
#  ('XP_018341148.1 PREDICTED: chymotrypsin inhibitor-like [Trachymyrmex septentrionalis]',
#   157),
#  ('XP_019528754.1 PREDICTED: chymotrypsin inhibitor [Aedes albopictus]', 157),
#  ('XP_015903671.1 PREDICTED: chymotrypsin inhibitor-like [Parasteatoda tepidariorum]',
#   157),
#  ('XP_017038381.1 PREDICTED: chymotrypsin inhibitor SCI-II [Drosophila kikkawai]',
#   157),
#  ('XP_017889438.1 PREDICTED: chymotrypsin inhibitor-like [Ceratina calcarata]',
#   157),
#  ('XP_014234598.1 PREDICTED: chymotrypsin B-like [Trichogramma pretiosum]',
#   157),
#  ('NP_001298172.1 lectizyme-like precursor [Stomoxys calcitrans]', 157),
#  ('XP_018057757.1 PREDICTED: chymotrypsin inhibitor [Atta colombica]', 158),
#  ('XP_018392608.1 PREDICTED: chymotrypsin inhibitor [Cyphomyrmex costatus]',
#   158),
# ...
#  ('XP_011379839.1 PREDICTED: prolactin [Pteropus vampyrus]', 223),
#  ('XP_018018125.1 PREDICTED: chymotrypsin A-like, partial [Hyalella azteca]',
#   225),
#  ('YP_233898.1 peptidase S1, chymotrypsin [Pseudomonas syringae pv. syringae B728a]',
#   225),
#  ('XP_013147136.1 PREDICTED: chymotrypsin B-like [Papilio polytes]', 231),
#  ('XP_013168737.1 PREDICTED: chymotrypsin B-like [Papilio xuthus]', 231),
#  ('XP_019616229.1 PREDICTED: chymotrypsin B-like [Branchiostoma belcheri]',
#   241),
#  ('XP_019620223.1 PREDICTED: chymotrypsin B-like [Branchiostoma belcheri]',
#   242),
#  ('XP_015904164.1 PREDICTED: LOW QUALITY PROTEIN: chymotrypsin B-like [Parasteatoda tepidariorum]',
#   245),
#  ('XP_019894519.1 PREDICTED: chymotrypsin BI-like [Musca domestica]', 247),
#  ('NP_001305952.1 prolactin regulatory element binding [Gallus gallus]', 248),
#  ('NP_057912.2 prolactin regulatory element-binding protein isoform 1 [Mus musculus]',
#   250),
#  ('NP_037520.1 prolactin regulatory element-binding protein isoform 1 [Homo sapiens]',
#   251),
#  ('NP_001164179.1 prolactin regulatory element-binding protein [Rattus norvegicus]',
#   251),
#  ('NP_001070343.2 prolactin regulatory element-binding protein [Bos taurus]',
#   252),
#  ('XP_017844126.1 PREDICTED: LOW QUALITY PROTEIN: chymotrypsin BI-like [Drosophila busckii]',
#   261),
#  ('XP_017843768.1 PREDICTED: chymotrypsin BI-like [Drosophila busckii]', 262),
#  ('XP_016933396.1 PREDICTED: chymotrypsin BI [Drosophila suzukii]', 271),
#  ('XP_016955518.1 PREDICTED: chymotrypsin BI [Drosophila biarmipes]', 271),
#  ('XP_017071233.1 PREDICTED: chymotrypsin BI [Drosophila eugracilis]', 272),
#  ('XP_015916653.1 PREDICTED: chymotrypsin B-like [Parasteatoda tepidariorum]',
#   275),
#  ('XP_015903313.1 PREDICTED: chymotrypsin B-like [Parasteatoda tepidariorum]',
#   275),
#  ('XP_017121712.1 PREDICTED: chymotrypsin BI [Drosophila elegans]', 276),
#  ('XP_015788804.1 PREDICTED: chymotrypsin B-like [Tetranychus urticae]', 277),
#  ('XP_017048584.1 PREDICTED: chymotrypsin BI [Drosophila ficusphila]', 277),
#  ('XP_016983312.1 PREDICTED: chymotrypsin BI [Drosophila rhopaloa]', 278),
#  ('XP_017012397.1 PREDICTED: chymotrypsin BI [Drosophila takahashii]', 278),
#  ('XP_017101394.1 PREDICTED: chymotrypsin BI [Drosophila bipectinata]', 279),
#  ('NP_001106972.1 prolactin receptor b [Danio rerio]', 279),
#  ('XP_017017839.1 PREDICTED: chymotrypsin BI [Drosophila kikkawai]', 281),
#  ('XP_017001162.1 PREDICTED: chymotrypsin A [Drosophila takahashii]', 283),
#  ('XP_017001161.1 PREDICTED: chymotrypsin A [Drosophila takahashii]', 283),
#  ('XP_019961728.1 PREDICTED: chymotrypsin B-like, partial [Paralichthys olivaceus]',
#   284),
#  ('XP_019641918.1 PREDICTED: chymotrypsin B-like [Branchiostoma belcheri]',
#   303),
#  ('XP_002124963.1 PREDICTED: chymotrypsin B-like [Ciona intestinalis]', 305),
#  ('XP_017785357.1 PREDICTED: chymotrypsin BI-like [Nicrophorus vespilloides]',
#   309),
#  ('YP_237955.1 peptidase S1, chymotrypsin [Pseudomonas syringae pv. syringae B728a]',
#   317),
#  ('NP_001072093.1 prolactin receptor precursor [Takifugu rubripes]', 328),
#  ('NP_001266551.1 prolactin receptor 2 precursor [Oreochromis niloticus]',
#   338),
#  ('NP_001191243.1 prolactin receptor isoform 6 precursor [Homo sapiens]', 339),
#  ('WP_034525436.1 glycoside hydrolase, partial [Bacteroides uniformis]', 344),
#  ('NP_001316269.1 prolactin receptor-like precursor [Kryptolebias marmoratus]',
#   348),
#  ('WP_013992390.1 glycoside hydrolase [Zobellia galactanivorans]', 352),
#  ('NP_001272598.1 prolactin receptor precursor [Capra hircus]', 391),
#  ('NP_001034815.1 prolactin receptor long form precursor [Bos taurus]', 393),
#  ('NP_035299.4 prolactin receptor isoform 1 precursor [Mus musculus]', 413),
#  ('NP_001079205.1 prolactin receptor precursor [Xenopus laevis]', 414),
#  ('NP_001122149.1 prolactin receptor precursor [Danio rerio]', 415),
#  ('NP_001029283.1 prolactin receptor isoform a precursor [Rattus norvegicus]',
#   416),
#  ('NP_001079085.1 prolactin receptor precursor [Xenopus laevis]', 418),
#  ('NP_001075700.1 prolactin receptor precursor [Oryctolagus cuniculus]', 419),
#  ('NP_001001868.1 prolactin receptor precursor [Sus scrofa]', 428),
#  ('NP_000940.1 prolactin receptor isoform 1 precursor [Homo sapiens]', 428),
#  ('NP_001254666.1 prolactin receptor precursor [Callithrix jacchus]', 429),
#  ('WP_025017576.1 glycoside hydrolase [Bacteroides sartorii]', 430),
#  ('WP_052309582.1 glycoside hydrolase [Bacteroides cellulosilyticus]', 431),
#  ('WP_061433712.1 glycoside hydrolase [Bacteroides intestinalis]', 431),
#  ('WP_007217482.1 MULTISPECIES: glycoside hydrolase [Bacteroides]', 432),
#  ('WP_039939541.1 glycoside hydrolase [Alistipes sp. HGB5]', 433),
#  ('NP_001266477.1 prolactin receptor precursor [Oreochromis niloticus]', 434),
#  ('WP_032136116.1 glycoside hydrolase [Alistipes sp. AL-1]', 434),
#  ('NP_001316305.1 prolactin receptor precursor [Kryptolebias marmoratus]',
#   437),
#  ('WP_007839561.1 glycoside hydrolase [Bacteroides dorei]', 439),
#  ('WP_054406861.1 glycoside hydrolase [Flavobacterium akiainvivens]', 439),
#  ('NP_001118071.1 prolactin receptor precursor [Oncorhynchus mykiss]', 441),
#  ('WP_053472831.1 glycoside hydrolase [Flavobacterium sp. VMW]', 441),
#  ('WP_056201192.1 glycoside hydrolase [Flavobacterium sp. Root186]', 442),
#  ('WP_046375949.1 glycoside hydrolase [Spirosoma radiotolerans]', 442),
#  ('WP_041975087.1 glycoside hydrolase [Pyrinomonas methylaliphatogenes]', 442),
#  ('WP_005832946.1 MULTISPECIES: glycoside hydrolase [Bacteria]', 445),
#  ('WP_056869894.1 glycoside hydrolase [Pedobacter sp. Leaf194]', 447),
#  ('WP_035141760.1 glycoside hydrolase [Flavobacterium daejeonense]', 448),
#  ('WP_052353448.1 glycoside hydrolase [Dyadobacter tibetensis]', 451),
#  ('WP_029904864.1 glycoside hydrolase [Prevotella sp. 10(H)]', 452),
#  ('WP_044138155.1 glycoside hydrolase [Bacteroides oleiciplenus]', 454),
#  ('WP_008447207.1 glycoside hydrolase [Janthinobacterium sp. HH01]', 456),
#  ('WP_039138576.1 glycoside hydrolase [Flavihumibacter solisilvae]', 456),
#  ('WP_036632876.1 glycoside hydrolase [Parabacteroides distasonis]', 456),
#  ('WP_034531813.1 glycoside hydrolase [Bacteroides sp. 2_1_33B]', 456),
#  ('WP_009016476.1 glycoside hydrolase [Parabacteroides sp. D13]', 456),
#  ('WP_009275539.1 MULTISPECIES: glycoside hydrolase [Parabacteroides]', 457),
#  ('WP_036611156.1 glycoside hydrolase [Parabacteroides distasonis]', 457),
#  ('WP_048926883.1 MULTISPECIES: glycoside hydrolase [Parabacteroides]', 457),
#  ('WP_036651591.1 glycoside hydrolase [Parabacteroides distasonis]', 457),
#  ('WP_035447471.1 glycoside hydrolase [Bacteroides uniformis]', 458),
#  ('WP_036386408.1 glycoside hydrolase [Muricauda sp. MAR_2010_75]', 459),
#  ('WP_061412287.1 glycoside hydrolase [Bacteroides uniformis]', 460),
#  ('WP_034526403.1 glycoside hydrolase [Bacteroides sp. 3_1_19]', 461),
#  ('WP_015732107.1 glycoside hydrolase [Fibrobacter succinogenes]', 488),
#  ('WP_014545036.1 glycoside hydrolase [Fibrobacter succinogenes]', 490),
#  ('YP_002353556.1 glycoside hydrolase [Dictyoglomus turgidum DSM 6724]', 516),
#  ('WP_014546434.1 glycoside hydrolase [Fibrobacter succinogenes]', 526),
#  ('WP_014546433.1 glycoside hydrolase [Fibrobacter succinogenes]', 532),
#  ('WP_014546432.1 glycoside hydrolase [Fibrobacter succinogenes]', 534),
#  ('WP_026508271.1 glycoside hydrolase [Butyrivibrio sp. MC2013]', 537),
#  ('WP_052088517.1 glycoside hydrolase [Paenibacillus wynnii]', 540),
#  ('WP_027629187.1 glycoside hydrolase [[Clostridium] cellobioparum]', 541),
#  ('WP_062521850.1 glycoside hydrolase [Paenibacillus jilunlii]', 542),
#  ('YP_002352162.1 glycoside hydrolase [Dictyoglomus turgidum DSM 6724]', 543),
#  ('YP_002353609.1 glycoside hydrolase [Dictyoglomus turgidum DSM 6724]', 547),
#  ('WP_012860985.1 glycoside hydrolase [Sebaldella termitidis]', 550),
#  ('WP_042141438.1 glycoside hydrolase [Paenibacillus sp. FSL P4-0081]', 550),
#  ('WP_042216402.1 glycoside hydrolase [Paenibacillus borealis]', 551),
#  ('WP_039308362.1 glycoside hydrolase [Paenibacillus sp. IHB B 3415]', 551),
#  ('WP_042243056.1 glycoside hydrolase [Paenibacillus sp. FSL R5-0912]', 551),
#  ('YP_002352226.1 glycoside hydrolase [Dictyoglomus turgidum DSM 6724]', 552),
#  ('WP_058353203.1 glycoside hydrolase [Acetivibrio ethanolgignens]', 553),
#  ('WP_057245726.1 glycoside hydrolase [Duganella sp. Root198D2]', 555),
#  ('WP_051051609.1 glycoside hydrolase [Paenibacillus sonchi]', 555),
#  ('WP_055926896.1 glycoside hydrolase [Duganella sp. Root336D2]', 555),
#  ('WP_049817965.1 glycoside hydrolase [Thermosediminibacter oceani]', 555),
#  ('WP_060861482.1 glycoside hydrolase [Paenibacillus riograndensis]', 556),
#  ('WP_057266276.1 glycoside hydrolase [Duganella sp. Root1480D1]', 556),
#  ('WP_046507565.1 glycoside hydrolase [Paenibacillus riograndensis]', 557),
#  ('WP_045923871.1 glycoside hydrolase [Bifidobacterium asteroides]', 558),
#  ('WP_026486892.1 glycoside hydrolase [Caldanaerobius polysaccharolyticus]',
#   558),
#  ('WP_048620941.1 MULTISPECIES: glycoside hydrolase [Clostridiales]', 559),
#  ('WP_013253488.1 glycoside hydrolase [Sediminispirochaeta smaragdinae]', 561),
#  ('WP_013145806.1 glycoside hydrolase [Geobacillus sp. C56-T3]', 561),
#  ('WP_042832687.1 glycoside hydrolase [Thermoanaerobacter sp. YS13]', 563),
#  ('WP_049684840.1 glycoside hydrolase [Thermoanaerobacter kivui]', 563),
#  ('WP_028991530.1 glycoside hydrolase [Thermoanaerobacter thermocopriae]',
#   563),
#  ('WP_009052646.1 MULTISPECIES: glycoside hydrolase [Thermoanaerobacter]',
#   563),
#  ('WP_034334870.1 glycoside hydrolase [Deinococcus misasensis]', 564),
#  ('WP_052233411.1 MULTISPECIES: glycoside hydrolase [Massilia]', 564),
#  ('WP_014758394.1 glycoside hydrolase [Thermoanaerobacterium aotearoense]',
#   564),
#  ('WP_057978747.1 glycoside hydrolase [Caloramator mitchellensis]', 565),
#  ('WP_052170963.1 glycoside hydrolase [Massilia sp. JS1662]', 565),
#  ('WP_038493900.1 glycoside hydrolase [Janthinobacterium agaricidamnosum]',
#   565),
#  ('WP_045412081.1 glycoside hydrolase [Thermoanaerobacterium saccharolyticum]',
#   565),
#  ('WP_052828174.1 glycoside hydrolase [Bifidobacterium breve]', 565),
#  ('WP_052829163.1 glycoside hydrolase [Bifidobacterium breve]', 565),
#  ('WP_056330197.1 glycoside hydrolase [Massilia sp. Root1485]', 566),
#  ('WP_056126461.1 glycoside hydrolase [Massilia sp. Root133]', 566),
#  ('WP_045164477.1 glycoside hydrolase [Thermoanaerobacter cellulolyticus]',
#   566),
#  ('WP_056439476.1 glycoside hydrolase [Massilia sp. Root335]', 566),
#  ('WP_051077220.1 glycoside hydrolase [Janthinobacterium sp. HH01]', 566),
#  ('WP_032739191.1 glycoside hydrolase [Bifidobacterium breve]', 566),
#  ('WP_054870958.1 glycoside hydrolase [Caloranaerobacter sp. TR13]', 567),
#  ('WP_040683988.1 glycoside hydrolase [Thermobrachium celere]', 567),
#  ('WP_056401569.1 glycoside hydrolase [Massilia sp. Root418]', 567),
#  ('WP_048730658.1 glycoside hydrolase [Gardnerella vaginalis]', 567),
#  ('WP_043883931.1 glycoside hydrolase [Caldanaerobacter subterraneus]', 567),
#  ('WP_054265629.1 glycoside hydrolase [Janthinobacterium sp. CG23_2]', 568),
#  ('WP_028986433.1 glycoside hydrolase [Thermicanus aegyptius]', 568),
#  ('WP_039763658.1 glycoside hydrolase [Caldicellulosiruptor sp. F32]', 568),
#  ('WP_057158700.1 glycoside hydrolase [Massilia sp. Root351]', 568),
#  ('WP_045173786.1 glycoside hydrolase [Caldicellulosiruptor sp. Wai35.B1]',
#   569),
#  ('WP_050410054.1 glycoside hydrolase [Massilia sp. NR 4-1]', 569),
#  ('WP_056342519.1 glycoside hydrolase [Massilia sp. Leaf139]', 569),
#  ('WP_029229245.1 glycoside hydrolase [Caldicellulosiruptor acetigenus]', 570),
#  ('WP_039892685.1 glycoside hydrolase [Hungatella hathewayi]', 570),
#  ('WP_007620931.1 glycoside hydrolase [Gordonia soli]', 571),
#  ('WP_003980960.1 MULTISPECIES: glycoside hydrolase [Streptomyces]', 571),
#  ('WP_025531388.1 glycoside hydrolase [Hungatella hathewayi]', 572),
#  ('WP_005175695.1 glycoside hydrolase [Gordonia aichiensis]', 574),
#  ('WP_048551310.1 glycoside hydrolase [Tetrasphaera japonica]', 576),
#  ('YP_003317062.1 glycoside hydrolase [Thermanaerovibrio acidaminovorans DSM 6589]',
#   579),
#  ('WP_013152157.1 glycoside hydrolase [Nocardiopsis dassonvillei]', 581),
#  ('WP_051235552.1 glycoside hydrolase [Marinimicrobium agarilyticum]', 582),
#  ('WP_036437368.1 glycoside hydrolase [Mycobacterium mageritense]', 583),
#  ('WP_013048627.1 glycoside hydrolase [Aminobacterium colombiense]', 592),
#  ('YP_002352033.1 glycoside hydrolase [Dictyoglomus turgidum DSM 6724]', 601),
#  ('NP_001290088.1 prolactin receptor precursor [Meleagris gallopavo]', 615),
#  ('NP_001269751.1 prolactin receptor precursor [Columba livia]', 616),
#  ('NP_990185.1 prolactin receptor precursor [Gallus gallus]', 617),
#  ('NP_001297329.1 prolactin receptor precursor [Anas platyrhynchos]', 619),
#  ('WP_029428991.1 glycoside hydrolase [Bacteroides cellulosilyticus]', 690),
#  ('WP_061437479.1 glycoside hydrolase [Bacteroides intestinalis]', 690),
#  ('WP_060407569.1 glycoside hydrolase [Bacteroides cellulosilyticus]', 690),
#  ('WP_007660272.1 glycoside hydrolase [Bacteroides intestinalis]', 690),
#  ('WP_044533624.1 glycoside hydrolase [Bacteroides intestinalis]', 690),
#  ('WP_032933421.1 glycoside hydrolase [Bacteroides sp. 9_1_42FAA]', 690),
#  ('WP_044153528.1 glycoside hydrolase [Bacteroides cellulosilyticus]', 690),
#  ('WP_044164967.1 glycoside hydrolase [Bacteroides reticulotermitis]', 691),
#  ('WP_040312544.1 glycoside hydrolase [Bacteroides plebeius]', 691),
#  ('WP_044267414.1 glycoside hydrolase [Bacteroides timonensis]', 692),
#  ('WP_025018431.1 glycoside hydrolase [Bacteroides sartorii]', 692),
#  ('WP_032952943.1 glycoside hydrolase [Bacteroides vulgatus]', 692),
#  ('YP_002352255.1 glycoside hydrolase [Dictyoglomus turgidum DSM 6724]', 711),
#  ('WP_003980150.1 MULTISPECIES: glycoside hydrolase [Streptomyces]', 732),
#  ('WP_013616935.1 glycoside hydrolase [Bacteroides salanitronis]', 782),
#  ('WP_007568814.1 glycoside hydrolase [Bacteroides coprocola]', 785),
#  ('WP_007666410.1 glycoside hydrolase [Bacteroides intestinalis]', 837),
#  ('WP_007212771.1 glycoside hydrolase [Bacteroides cellulosilyticus]', 838),
#  ('WP_034752684.1 glycoside hydrolase [Bacteroides cellulosilyticus]', 838),
#  ('WP_044533509.1 glycoside hydrolase [Bacteroides intestinalis]', 838),
#  ('WP_061436517.1 glycoside hydrolase [Bacteroides intestinalis]', 838),
#  ('WP_033160695.1 glycoside hydrolase [Bacteroides cellulosilyticus]', 838),
#  ('WP_044270036.1 glycoside hydrolase [Bacteroides timonensis]', 841),
#  ('WP_044974539.1 glycoside hydrolase [Ruminococcus sp. HUN007]', 1053),
#  ('WP_031563296.1 glycoside hydrolase [Ruminococcus flavefaciens]', 1054),
#  ('WP_057305593.1 glycoside hydrolase [Paenibacillus sp. Root444D2]', 1057),
#  ('WP_060646106.1 glycoside hydrolase [Paenibacillus sp. Soil724D2]', 1057),
#  ('WP_036718859.1 glycoside hydrolase [Paenibacillus harenae]', 1058),
#  ('WP_041048068.1 glycoside hydrolase [Paenibacillus sp. VKM B-2647]', 1058),
#  ('WP_057314073.1 glycoside hydrolase [Paenibacillus sp. Soil766]', 1059),
#  ('WP_009987618.1 glycoside hydrolase [Ruminococcus flavefaciens]', 1062),
#  ('WP_028519409.1 glycoside hydrolase [Ruminococcus flavefaciens]', 1064),
#  ('WP_037299935.1 glycoside hydrolase [Ruminococcus flavefaciens]', 1070),
#  ('WP_028514253.1 glycoside hydrolase [Ruminococcus flavefaciens]', 1078),
#  ('WP_014651141.1 glycoside hydrolase [Paenibacillus mucilaginosus]', 1079),
#  ('WP_028517867.1 glycoside hydrolase [Ruminococcus flavefaciens]', 1079),
#  ('WP_061801220.1 glycoside hydrolase [Bacillus circulans]', 1137),
#  ('WP_047943319.1 glycoside hydrolase [Bacillus circulans]', 1137),
#  ('WP_007083233.1 glycoside hydrolase [Bacillus bataviensis]', 1142),
#  ('WP_057981680.1 glycoside hydrolase [Virgibacillus soli]', 1142),
#  ('WP_034332166.1 glycoside hydrolase [Bacillus sp. J37]', 1142),
#  ('WP_046515432.1 glycoside hydrolase [Bacillus sp. SA1-12]', 1144),
#  ('WP_035445777.1 glycoside hydrolase [Bacillus sp. UNC41MFS5]', 1147),
#  ('WP_062323295.1 glycoside hydrolase [Paenibacillus pabuli]', 1152),
#  ('WP_015844434.1 glycoside hydrolase [Paenibacillus sp. JDR-2]', 1153)]

# %%
sorted_LD[:10]
# Out:
# [('NP_001157030.1 prolactin precursor [Homo sapiens]', 0),
#  ('XP_011513055.1 PREDICTED: prolactin isoform X1 [Homo sapiens]', 1),
#  ('XP_011513056.1 PREDICTED: prolactin isoform X1 [Homo sapiens]', 1),
#  ('XP_014991125.1 PREDICTED: prolactin isoform X2 [Macaca mulatta]', 2),
#  ('XP_002816520.2 PREDICTED: prolactin [Pongo abelii]', 2),
#  ('NP_001040593.1 prolactin precursor [Macaca mulatta]', 2),
#  ('XP_005553987.1 PREDICTED: prolactin isoform X2 [Macaca fascicularis]', 3),
#  ('XP_011740959.1 PREDICTED: prolactin isoform X2 [Macaca nemestrina]', 3),
#  ('XP_018885279.1 PREDICTED: prolactin [Gorilla gorilla gorilla]', 3),
#  ('XP_011886824.1 PREDICTED: prolactin isoform X2 [Cercocebus atys]', 3)]
